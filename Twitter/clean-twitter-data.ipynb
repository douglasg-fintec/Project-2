# %%
# Import the required libraries and dependencies
import os
import re
from pathlib import Path
import pandas as pd
from dotenv import load_dotenv
from bs4 import BeautifulSoup
import re

# %%
twitter_df = pd.read_csv(
    Path('../TWITTER/twitter_data.csv'),
    header = None,
    parse_dates=True,
    infer_datetime_format=True).dropna()

twitter_df.head()
# Out:
#                                                    0  1  2  \
# 0  b'JOI, humiliation tasks, and foot worship ses...  0  0
# 1  b'We have two choice hold $CEI or sell $CEI . ...  0  0
# 2  b'Anyone selling foot or lip pics DM me or com...  1  0
# 3  b'RT @LuisNav14: Stocks I\xe2\x80\x99m either ...  0  1
# 4  b'Stocks I\xe2\x80\x99m either in or watching ...  6  1
#
#                      3
# 0  2021-10-03 23:59:05
# 1  2021-10-03 23:58:54
# 2  2021-10-03 23:51:15
# 3  2021-10-03 23:49:44
# 4  2021-10-03 23:47:22

# %%
tweets_df = twitter_df.iloc[:,[3,0]]
tweets_df.columns = ['Date','Tweet']

tweets_df
# Out:
#                      Date                                              Tweet
# 0     2021-10-03 23:59:05  b'JOI, humiliation tasks, and foot worship ses...
# 1     2021-10-03 23:58:54  b'We have two choice hold $CEI or sell $CEI . ...
# 2     2021-10-03 23:51:15  b'Anyone selling foot or lip pics DM me or com...
# 3     2021-10-03 23:49:44  b'RT @LuisNav14: Stocks I\xe2\x80\x99m either ...
# 4     2021-10-03 23:47:22  b'Stocks I\xe2\x80\x99m either in or watching ...
# ...                   ...                                                ...
# 1308  2021-09-27 00:40:50  b"@unusual_whales A lot of butt hurt people in...
# 1309  2021-09-27 00:39:57  b"@facelessf3mme @unusual_whales This guy sell...
# 1310  2021-09-27 00:31:00  b'RT @LuisNav14: Stocks I\xe2\x80\x99m either ...
# 1311  2021-09-27 00:14:38  b'RT @likeagirlfrnd: unless youre looking for ...
# 1312  2021-09-27 00:06:11  b'Thinking of a couple names when it\xe2\x80\x...
#
# [1313 rows x 2 columns]

# %%
def remove_mentions(input_txt):
 #remove mentions
   pattern = r'@[A-Za-z0-9]+' 
   input_txt = re.sub(pattern, '',input_txt)     
   return input_txt

# %%
def remove_hash_tags(input_txt):
 #remove mentions
   pattern = r'#[A-Za-z0-9]+' 
   input_txt = re.sub(pattern, '',input_txt)     
   return input_txt

# %%
def remove_urls(input_txt):
 #remove mentions
   pattern = r'https?://[A-Za-z0-9./]+' 
   input_txt = re.sub(pattern, '',input_txt)     
   return input_txt

# %%
def remove_special_characters(input_txt):
 #remove mentions
   pattern = r'[!@#%^&*(),.?":{}|_<>]'
   input_txt = re.sub(pattern, '',input_txt)     
   return input_txt

   #[!@#$%^&*(),.?":{}|_<>]

# %%
def remove_html(input_txt):
    input_txt = BeautifulSoup(input_txt).get_text()
    return input_txt

# %%
def remove_retweet(input_txt):
 #remove mentions
   pattern = r'^[RT \s]+' 
   input_txt = re.sub(pattern, '',input_txt)     
   return input_txt

# %%
clean_tweets = []

for tweet in tweets_df['Tweet']:
  
#remove the first character of the string
# Remove first character from string if matches 'b'
  tweet = tweet.lstrip('b')

 #Remove mentions
  tweet = remove_mentions(tweet)

   #Remove Hash Tags
  tweet = remove_hash_tags(tweet)

  # Remove Hash Tags
  tweet = remove_urls(tweet)

  tweet = remove_special_characters(tweet)

 #remove html characters
  tweet = remove_html(tweet)

 #Remove the retweet symbol
  tweet = remove_retweet(tweet)


 # make all letters lower case - avoids case sensitive issues with the model
  tweet = tweet.lower()
 
  cleaned = tweet.decode("utf-8-sig").replace(u"\ufffd", "?")
  clean_tweets.append(tweet)

# %%
clean_tweets_df = pd.DataFrame(clean_tweets,columns=['tweet'])
clean_tweets_df['date'] = tweets_df['Date']
clean_tweets_df
# Out:
#                                                   tweet                 date
# 0     'joi humiliation tasks and foot worship sessio...  2021-10-03 23:59:05
# 1     'we have two choice hold $cei or sell $cei  yo...  2021-10-03 23:58:54
# 2     'anyone selling foot or lip pics dm me or comm...  2021-10-03 23:51:15
# 3     'rt  stocks i\xe2\x80\x99m either in or watchi...  2021-10-03 23:49:44
# 4     'stocks i\xe2\x80\x99m either in or watching t...  2021-10-03 23:47:22
# ...                                                 ...                  ...
# 1308  whales a lot of butt hurt people in here i gue...  2021-09-27 00:40:50
# 1309  whales this guy sells and doesn't over old nig...  2021-09-27 00:39:57
# 1310  'rt  stocks i\xe2\x80\x99m either in or watchi...  2021-09-27 00:31:00
# 1311  'rt  unless youre looking for a dickrate or be...  2021-09-27 00:14:38
# 1312  'thinking of a couple names when it\xe2\x80\x9...  2021-09-27 00:06:11
#
# [1313 rows x 2 columns]

# %%
output = Path('../TWITTER/twitter_data_CLEANED.csv')
clean_tweets_df.to_csv(output)
