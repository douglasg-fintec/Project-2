# %%
# Import the required libraries and dependencies
import os
from pathlib import Path
import tweepy as tw
import pandas as pd
from dotenv import load_dotenv

# %%
# Load the .env file into the notebook

load_dotenv()

# Read in Twitter API keys and API secrets
consumer_key=consumer_key = os.getenv("TWITTER_CONSUMER_KEY")
consumer_secret = os.getenv("TWITTER_CONSUMER_SECRET")
access_token = os.getenv("TWITTER_ACCESS_TOKEN")
access_token_secret =os.getenv("TWITTER_ACCESS_TOKEN_SECRET")

# Read in Twitter Bearer Token
bearer_token = os.getenv("TWITTER_BEARER_TOKEN")

# %%
# Authenticate 
# auth = tw.OAuthHandler(my_api_key, my_api_secret)
auth = tw.AppAuthHandler(consumer_key, consumer_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
#enter your words to create query
search_words = "#CEI"      
search_query = search_words + " -filter:retweets"

# Set Tweet Search Parameters
fromDate="202010010000"
toDate="202010010000"

    #Get tweets
tweets = tw.Cursor(api.search_tweets, 
    q=search_query, 
    lang='en',
    result_type="mixed").items(50)

 # Store the API responses in a list
tweets_copy = []
for tweet in tweets:
    tweets_copy.append(tweet)

# %%
#Inialize the dataframe

tweets_df =pd.DataFrame()

# intialize the dataframe
tweets_df = pd.DataFrame()

# populate the dataframe
for tweet in tweets_copy:
    hashtags = []
    try:
        for hashtag in tweet.entities["hashtags"]:
            hashtags.append(hashtag["text"])
        text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
    except:
        pass
    tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name, 
                                               'user_location': tweet.user.location,\
                                               'user_description': tweet.user.description,
                                               'user_verified': tweet.user.verified,
                                               'date': tweet.created_at,
                                               'text': text, 
                                               'hashtags': [hashtags if hashtags else None],
                                               'source': tweet.source}))
    tweets_df = tweets_df.reset_index(drop=True)

# show the dataframe
tweets_df.head()
# Out:
#         user_name user_location  \
# 0        Blue Jay
# 1  StockBanditBob          Ohio
# 2     Destiny Doa       Florida
# 3   Queen grier😈💋   Tribute 20$
# 4       topstonks
#
#                                     user_description  user_verified  \
# 0                                                             False
# 1  Daytrader. Tweets are not advice. I'm not a fi...          False
# 2  Entrepreneur, Model, Dominatrix and pornstar. ...          False
# 3  SELLING NUDES & SESSIONS😏. I accept: PAYPAL, A...          False
# 4  Wanna know where #stonks are in the hype cycle...          False
#
#                        date  \
# 0 2021-10-02 14:28:26+00:00
# 1 2021-10-02 13:57:59+00:00
# 2 2021-10-02 13:55:17+00:00
# 3 2021-10-02 13:46:18+00:00
# 4 2021-10-02 13:45:58+00:00
#
#                                                 text  \
# 0  @MrZackMorris lots of mixed messages about opt...
# 1  How many times have you jumped in late to a st...
# 2  Which one of you weak little betas wants  to p...
# 3  Weak pet.. I can easily #brainwash you.\n\n#fi...
# 4  $CEI working it's way into the top 10 most men...
#
#                                             hashtags              source
# 0                                              [CEI]  Twitter for iPhone
# 1                                               None     Twitter Web App
# 2     [Findom, Femdom, paypig, simp, beta, joi, sph]  Twitter for iPhone
# 3  [brainwash, findom, debts, blackmail, smokingf...  Twitter for iPhone
# 4                                               None           topstonks

# %%
# Write tweet dataframe to a CSV file
tweets_df.to_csv(Path('./Resources/twitter_data.csv'),encoding='utf-8',index=None,header=True)
